# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the datasets *student-mat* and *student-por* and merge them.

# %%
mat=pd.read_csv('C:/Users/ACER/Desktop/Analytixlabs/Python/Manuj_Sir_python/Assignment/Exercise Data Files/Pandas Exercise Lambda Functions Files/student-mat.csv')
por=pd.read_csv('C:/Users/ACER/Desktop/Analytixlabs/Python/Manuj_Sir_python/Assignment/Exercise Data Files/Pandas Exercise Lambda Functions Files/student-por.csv')

# %%
por.head(2)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences G1  G2  G3
# 0      4        3      4     1     1      3        4  0  11  11
# 1      5        3      3     1     1      3        2  9  11  11
#
# [2 rows x 33 columns]

# %%
mat.head(2)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences G1 G2 G3
# 0      4        3      4     1     1      3        6  5  6  6
# 1      5        3      3     1     1      3        4  5  5  6
#
# [2 rows x 33 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df=pd.concat([mat,por],axis=0)

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.drop(columns=['traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],inplace=True)

# %%
df.head(2)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home    other
#
#    reason guardian
# 0  course   mother
# 1  course   father

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
captalize=lambda x: x.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df[['Mjob','Fjob']].applymap(captalize)
# Out:
#          Mjob      Fjob
# 0     At_home   Teacher
# 1     At_home     Other
# 2     At_home     Other
# 3      Health  Services
# 4       Other     Other
# ..        ...       ...
# 644  Services     Other
# 645   Teacher  Services
# 646     Other     Other
# 647  Services  Services
# 648  Services     Other
#
# [1044 rows x 2 columns]

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
df[['Mjob','Fjob']]=df[['Mjob','Fjob']].applymap(captalize)
df.tail(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  Services     Other
# 645     MS   F   18       U     LE3       T     3     1   Teacher  Services
# 646     MS   F   18       U     GT3       T     1     1     Other     Other
# 647     MS   M   17       U     LE3       T     3     1  Services  Services
# 648     MS   M   18       R     LE3       T     3     2  Services     Other
#
#      reason guardian
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
#taking 18 years as legal age to drink
def majority(x):
    if x >18:
        return True
    else:
        return False

# %%
df['legal_drinker']=df.age.apply(majority)

# %%
df.head(4)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
#
#    reason guardian  legal_drinker
# 0  course   mother          False
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.

# %%
df.select_dtypes(['int64']).apply(lambda x : x*10)
# Out:
#      age  Medu  Fedu
# 0    180    40    40
# 1    170    10    10
# 2    150    10    10
# 3    150    40    20
# 4    160    30    30
# ..   ...   ...   ...
# 644  190    20    30
# 645  180    30    10
# 646  180    10    10
# 647  170    30    10
# 648  180    30    20
#
# [1044 rows x 3 columns]
